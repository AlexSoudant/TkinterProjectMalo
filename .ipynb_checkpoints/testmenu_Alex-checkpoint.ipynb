# %%
import Tkinter as tk



class application(tk.Tk):



    def __init__(self, *args, **kwargs):





        #image = tk.Image.open('KFC.png')

        #backgroundImage = tk.PhotoImage(image)

        

        tk.Tk.__init__(self, *args, **kwargs)

        container = tk.Frame(self)#, width=400, height=400)



        container.pack(side="top", fill="both", expand = True)



        container.grid_rowconfigure(0, weight=1)

        container.grid_columnconfigure(0, weight=1)



        self.frames = {}



        for F in (Root, Jouer, Fouiller, Interroger, Jardinier, Corps, Maison, Mari, Jessica, Bureau, Majordome, Final, Coupable, Gagner, Perdu, Conclusion):



            frame = F(container, self)



            self.frames[F] = frame



            frame.grid(row=0, column=0, sticky="nsew")




        # Jouer
        self.show_frame(Root)



    def show_frame(self, cont):



        frame = self.frames[cont]

        frame.tkraise()





class Jouer(tk.Frame):



    def __init__(self, parent, controller):

        tk.Frame.__init__(self, parent)

        label = tk.Label(self, text="Intrigue")

        label.pack()

        



        bouton1 = tk.Button(self, text="fouiller le corps", command=lambda: controller.show_frame(Fouiller), width=20, height=2)

        bouton1.pack()

        #bouton1.place(x=0,y=650)



        bouton2 = tk.Button(self, text="interroger les témoins", command=lambda: controller.show_frame(Interroger), width=20, height=2)

        bouton2.pack()

        #bouton2.place(x=350,y=650)





class Fouiller(tk.Frame):



    def __init__(self, parent, controller):

        tk.Frame.__init__(self, parent)

        #self.geometry("500x700+500+0")

        #self.title("Projet ISN")



        bouton1 = tk.Button(self, text="fouiller le corps", command=lambda: controller.show_frame(Corps), width=20, height=2)

        bouton1.pack()



        bouton2 = tk.Button(self, text="fouiller la maison", command=lambda: controller.show_frame(Maison), width=20, height=2)

        bouton2.pack()        



        

class Interroger(tk.Frame):

    def __init__(self, parent, controller):

        tk.Frame.__init__(self, parent)

        #self.geometry("500x700+500+0")



        bouton1 = tk.Button(self, text="décrypter et utiliser le code", command=lambda: controller.show_frame(Code), width=20, height=2)

        bouton1.pack()



        bouton2 = tk.Button(self, text="interroger le jardinier", command=lambda: controller.show_frame(Jardinier), width=20, height=2)

        bouton2.pack()

        



class Corps(tk.Frame):

    def __init__(self, parent, controller):

        tk.Frame.__init__(self, parent)

        #self.geometry("500x700+500+0")



        bouton1 = tk.Button(self, text="Interroger Jessica", command=lambda: controller.show_frame(Jessica), width=20, height=2)

        bouton1.pack()

        

        bouton2 = tk.Button(self, text="Interroger le mari", command=lambda: controller.show_frame(Mari), width=20, height=2)

        bouton2.pack()





class Jardinier(tk.Frame):

    def __init__(self, parent, controller):

        tk.Frame.__init__(self, parent)

        #self.geometry("500x700+500+0")



        bouton1 = tk.Button(self, text="Aller ouvrir le bureau", command=lambda: controller.show_frame(Bureau), width=20, height=2)

        bouton1.pack()



        bouton2 = tk.Button(self, text="Interroger le mari", command=lambda: controller.show_frame(Mari), width=20, height=2)

        bouton2.pack()

        

"""

class Code(tk.Frame):

    def Verification():

        if motDePasse.get() == "coucou":

            showinfo("Résultat","Mot de passe correct.\nAu revoir !")

            maFenetre.destroy()

        else:

            showwarning("Résultat","Mot de passe incorrect.\Veuillez recommencer !")

            motDePasse.set('')

    maFenetre = Tk()

    maFenetre.title('Identification requise')



    Label1 = Label(maFenetre, text = "Mot de passe ")

    Label1.pack(side = LEFT, padx = 5, pady = 5)



    motDePasse = StringVar()

    champ = Entry(maFenetre, textvariable = motDePasse, show="*", bg="bisque", fg="maroon")

    champ.focus_set()

    champ.pack(side = LEFT, padx = 5, pady = 5)



    bouton = Button(maFenetre, text="Valider", command = Verification)

    bouton.pack(side = LEFT, padx = 5, pady = 5)



    maFenetre.mainloop()

""" 

        



class Maison(tk.Frame):

    def __init__(self, parent, controller):

        tk.Frame.__init__(self, parent)

        #self.geometry("500x700+500+0")



        bouton1 = tk.Button(self, text="Interroger le majordome", command=lambda: controller.show_frame(Majordome), width=20, height=2)

        bouton1.pack()



        bouton2 = tk.Button(self, text="Interroger Jessica", command=lambda: controller.show_frame(Jessica), width=20, height=2)

        bouton2.pack()





class Mari(tk.Frame):

    def __init__(self, parent, controller):

        tk.Frame.__init__(self, parent)

        #self.geometry("500x700+500+0")



        bouton = tk.Button(self, text="Suite", command=lambda: controller.show_frame(Final), width=20, height=2)

        bouton.pack()





class Jessica(tk.Frame):

    def __init__(self, parent, controller):

        tk.Frame.__init__(self, parent)

        #self.geometry("500x700+500+0")



        bouton = tk.Button(self, text="Suite", command=lambda: controller.show_frame(Final), width=20, height=2)

        bouton.pack()





class Bureau(tk.Frame):

    def __init__(self, parent, controller):

        tk.Frame.__init__(self, parent)

        #self.geometry("500x700+500+0")



        bouton = tk.Button(self, text="Suite", command=lambda: controller.show_frame(Final), width=20, height=2)

        bouton.pack()





class Majordome(tk.Frame):

    def __init__(self, parent, controller):

        tk.Frame.__init__(self, parent)

        #self.geometry("500x700+500+0")



        bouton = tk.Button(self, text="Suite", command=lambda: controller.show_frame(Final), width=20, height=2)

        bouton.pack()





class Final(tk.Frame):

    def __init__(self, parent, controller):

        tk.Frame.__init__(self, parent)

        #self.geometry("500x700+500+0")



        bouton = tk.Button(self, text="Proposer un coupable", command=lambda: controller.show_frame(Coupable), width=20, height=2)

        bouton.pack()



        bouton2 = tk.Button(self, text="Suite", command=lambda: controller.show_frame(Final), width=20, height=2)

        bouton2.pack()





class Coupable(tk.Frame):

    def __init__(self, parent, controller):

        tk.Frame.__init__(self, parent)

        #self.geometry("500x700+500+0")



        bouton1 = tk.Button(self, text="Le mari", command=lambda: controller.show_frame(Perdu), width=20, height=2)

        bouton1.pack()

        

        bouton2 = tk.Button(self, text="Jessica", command=lambda: controller.show_frame(Perdu), width=20, height=2)

        bouton2.pack()

        

        bouton3 = tk.Button(self, text="Le majordome", command=lambda: controller.show_frame(Gagner), width=20, height=2)

        bouton3.pack()

        

        bouton4 = tk.Button(self, text="Le jardinier", command=lambda: controller.show_frame(Perdu), width=20, height=2)

        bouton4.pack()





class Gagner(tk.Frame):

    def __init__(self, parent, controller):

        tk.Frame.__init__(self, parent)

        #self.geometry("500x700+500+0")



        bouton = tk.Button(self, text="Suite", command=lambda: controller.show_frame(Conclusion), width=20, height=2)

        bouton.pack()





class Perdu(tk.Frame):

    def __init__(self, parent, controller):

        tk.Frame.__init__(self, parent)

        #self.geometry("500x700+500+0")



        bouton = tk.Button(self, text="Suite", command=lambda: controller.show_frame(Conclusion), width=20, height=2)

        bouton.pack()





class Conclusion(tk.Frame):

    def __init__(self, parent, controller):

        tk.Frame.__init__(self, parent)

        #self.geometry("500x700+500+0")



        bouton = tk.Button(self, text="Quitter", command= close_window, width=20, height=2)

        bouton.pack()



        bouton1 = tk.Button(self, text="Rejouer", command=lambda: controller.show_frame(Jouer), width=20, height=2)

        bouton1.pack()




#if __name__ == "__main__":

#class Root(tk.Frame):
    
#    def __init__(self, parent, controller):
        

#        tk.Frame.__init__(self, parent)

    #root = tk.Tk()

#        self.geometry("500x700+500+0")

#        self.title("Projet ISN")



    #gif_img = tk.PhotoImage(file='KFC.png')



    #fond = tk.Label(image=gif_img) 

    #fond.image = gif_img 

    #fond.pack()



    #bouton_play=tk.Button(root, text="Jouer", command=lambda: controller.show_frame(Jouer), width=20, height=2)
    
    #bouton_play.pack()

    #bouton_exit=tk.Button(root, text="Quitter", command=root.destroy, width=20, height=2)
    
    #bouton_exit.pack()


    #bouton_play.place(x=0,y=650)

    #bouton_exit.place(x=350,y=650)


class Root(tk.Frame):

    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        
        #self.geometry("500x700+500+0")

        button1 = tk.Button(self, text="Jouer",
                            command=lambda: controller.show_frame(Jouer))
        button1.pack()

        button2 = tk.Button(self, text="Quitter",
                            command= close_window)
        button2.pack()
        
        button1.grid(row=1,column=0)
        button2.grid(row=0,column=1)
        
def close_window(): 
    app.destroy()
        
app = application()

# root.mainloop()
app.mainloop()
